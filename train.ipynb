# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/v3-1-1-weights/best.pt
# /kaggle/input/marinev5/yolov8m.pt
# /kaggle/input/marinev5/marinev5_kaggle/marinev5_kaggle/README.dataset.txt
# /kaggle/input/marinev5/marinev5_kaggle/marinev5_kaggle/README.roboflow.txt
# /kaggle/input/marinev5/marinev5_kaggle/marinev5_kaggle/data.yaml
# /kaggle/input/marinev5/marinev5_kaggle/marinev5_kaggle/valid/labels/16836753860_855f0f91d7_o_jpg.rf.afb44d9c55ebab437716a1851bd7cf86.txt
# /kaggle/input/marinev5/marinev5_kaggle/marinev5_kaggle/valid/labels/YI23CIDFYUSI_jpg.rf.1e9eaf1b2f37cbfe075bf7665736a51b.txt
# /kaggle/input/marinev5/marinev5_kaggle/marinev5_kaggle/valid/labels/two-lobsters-in-aquarium-2A365DN_jpg.rf.b02b77993d5c339c256d762790bb9026.txt
# /kaggle/input/marinev5/marinev5_kaggle/marinev5_kaggle/valid/labels/25463554767_7d662179f6_o_jpg.rf.993ab0318e4e43d4ffa8482951e0c80c.txt
# /kaggle/input/marinev5/marinev5_kaggle/marinev5_kaggle/valid/labels/38816007610_2a06fbbfc7_b_jpg.rf.e8df41153dc4dde6e36f0a11b5ce6c76.txt
# ...

# %%
# !pip install ultralytics
# Out:
# ...
#   Obtaining dependency information for ultralytics from https://files.pythonhosted.org/packages/e0/06/f07c56b8080af737ad42991fc1bb4e94da490c5227225c8337b8c248bd44/ultralytics-8.1.2-py3-none-any.whl.metadata
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.2/40.2 kB 709.8 kB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 699.7/699.7 kB 6.0 MB/s eta 0:00:00
# ...

# %%
import ultralytics
from ultralytics import YOLO
from IPython.display import display, Image
import os # operating system
from distutils.dir_util import copy_tree

# %%
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.1.2 🚀 Python-3.10.12 torch-2.0.0 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (4 CPUs, 31.4 GB RAM, 5359.4/8062.4 GB disk)

# %%
#delete the folders/directory
import shutil
import os

folder_path = '/kaggle/working/runs'

try:
    shutil.rmtree(folder_path)
    print(f"Successfully deleted: {folder_path}")
except Exception as e:
    print(f"Error deleting {folder_path}: {e}")
# Out:
# Error deleting /kaggle/working/runs: [Errno 2] No such file or directory: '/kaggle/working/runs'

# %%
#Delete the .zip files
import os

# Specify the file name
file_to_delete = 'runs_v5_thres50.zip'

# Construct the file path
file_path = '/kaggle/working/' + file_to_delete

# Check if the file exists before attempting to delete
if os.path.exists(file_path):
    # Delete the file
    os.remove(file_path)
    print(f'{file_to_delete} deleted successfully')
else:
    print(f'{file_to_delete} not found in the working directory')
# Out:
# runs_v5_thres50.zip not found in the working directory

# %%
# !ls
# Out:
# __notebook__.ipynb

# %%
# Git clone method (for development)
# !git clone https://github.com/ultralytics/ultralytics
# %pip install -qe ultralytics
# Out:
# Cloning into 'ultralytics'...
# remote: Enumerating objects: 20716, done.
# remote: Counting objects: 100% (1146/1146), done.
# remote: Compressing objects: 100% (703/703), done.
# remote: Total 20716 (delta 672), reused 728 (delta 428), pack-reused 19570
# Receiving objects: 100% (20716/20716), 12.25 MiB | 10.56 MiB/s, done.
# Resolving deltas: 100% (14375/14375), done.
# Note: you may need to restart the kernel to use updated packages.

# %%
mkdir /kaggle/working/ultralytics/mydata

# %%
mkdir /kaggle/working/ultralytics/mydata/train

# %%
mkdir /kaggle/working/ultralytics/mydata/valid

# %%
mkdir /kaggle/working/ultralytics/mydata/test

# %%
cd /kaggle/working/ultralytics/mydata
# Out:
# /kaggle/working/ultralytics/mydata

# %%
# !ls
# Out:
# test  train  valid

# %%
# Copy train images from kaggle input directory to kaggle output directory
fromDir = '/kaggle/input/marinev5/marinev5_kaggle/marinev5_kaggle/train'
toDirectory = '/kaggle/working/ultralytics/mydata/train'
copy_tree(fromDir, toDirectory)
# Out:
# ['/kaggle/working/ultralytics/mydata/train/labels/IRSFX61V7I1Y_jpg.rf.9aa434b4cad22485c689f51a5158d614.txt',
#  '/kaggle/working/ultralytics/mydata/train/labels/19489662540_85cce016a2_b_jpg.rf.b3af4e851ff54ff725cf0bd56bca0e38.txt',
#  '/kaggle/working/ultralytics/mydata/train/labels/0G2YDIPIWUFR_jpg.rf.6063cc614029b89a844cfd5819901a18.txt',
#  '/kaggle/working/ultralytics/mydata/train/labels/398516501_1005190cc0_o_jpg.rf.ec7c8979a00e9ffd508db8fdb1fca626.txt',
#  '/kaggle/working/ultralytics/mydata/train/labels/33559783566_5ffab1a5ea_o_jpg.rf.4893d0ec6fff2ac69b0a6003bc6c572c.txt',
#  '/kaggle/working/ultralytics/mydata/train/labels/7753843636_4ce5d987fc_o_jpg.rf.c582a5b1a60f19a2b1f891e31b050125.txt',
#  '/kaggle/working/ultralytics/mydata/train/labels/2220183388_c08a3d1015_o_jpg.rf.2171b5aac308b8aa7be2bf3a59653164.txt',
#  '/kaggle/working/ultralytics/mydata/train/labels/12094976564_6895956aff_o_jpg.rf.f0921748e744ae51b7149d63479c6523.txt',
# ...

# %%
# Copy test images from kaggle input directory to kaggle output directory
fromDir = '/kaggle/input/marinev5/marinev5_kaggle/marinev5_kaggle/test'
toDirectory = '/kaggle/working/ultralytics/mydata/test'
copy_tree(fromDir, toDirectory)
# Out:
# ['/kaggle/working/ultralytics/mydata/test/labels/IMG_2599_jpeg_jpg.rf.c8673f70ca7302ebc4dc21534b48c6ab.txt',
#  '/kaggle/working/ultralytics/mydata/test/labels/JellyFish-294-_jpg.rf.6c1de76697290aa725b1d9ed2f70a4a9.txt',
#  '/kaggle/working/ultralytics/mydata/test/labels/CFKH10FRFF0R_jpg.rf.6f7c8c439476488d90fbc4093f5afa25.txt',
#  '/kaggle/working/ultralytics/mydata/test/labels/RVQNYNS7GMZC_jpg.rf.790e0ad73a067d66e6f82a26ab470ebe.txt',
#  '/kaggle/working/ultralytics/mydata/test/labels/4610452536_afee891374_o_jpg.rf.fecbbb902ed274cbd01e922541051606.txt',
#  '/kaggle/working/ultralytics/mydata/test/labels/F53SZP03DYFC_jpg.rf.51e592379a7c91d2f36687e01f14ad1e.txt',
#  '/kaggle/working/ultralytics/mydata/test/labels/IMG_2481_jpeg_jpg.rf.048c1ce93f1cdf6bbcb185a53c7d1237.txt',
#  '/kaggle/working/ultralytics/mydata/test/labels/JellyFish-14-_jpg.rf.e09c34571214f52288a2d504dadf9154.txt',
# ...

# %%
# Copy valid images from kaggle input directory to kaggle output directory
fromDir = '/kaggle/input/marinev5/marinev5_kaggle/marinev5_kaggle/valid'
toDirectory = '/kaggle/working/ultralytics/mydata/valid'
copy_tree(fromDir, toDirectory)
# Out:
# ['/kaggle/working/ultralytics/mydata/valid/labels/16836753860_855f0f91d7_o_jpg.rf.afb44d9c55ebab437716a1851bd7cf86.txt',
#  '/kaggle/working/ultralytics/mydata/valid/labels/YI23CIDFYUSI_jpg.rf.1e9eaf1b2f37cbfe075bf7665736a51b.txt',
#  '/kaggle/working/ultralytics/mydata/valid/labels/two-lobsters-in-aquarium-2A365DN_jpg.rf.b02b77993d5c339c256d762790bb9026.txt',
#  '/kaggle/working/ultralytics/mydata/valid/labels/25463554767_7d662179f6_o_jpg.rf.993ab0318e4e43d4ffa8482951e0c80c.txt',
#  '/kaggle/working/ultralytics/mydata/valid/labels/38816007610_2a06fbbfc7_b_jpg.rf.e8df41153dc4dde6e36f0a11b5ce6c76.txt',
#  '/kaggle/working/ultralytics/mydata/valid/labels/MET0U5AWDDQI_jpg.rf.8041174d9dca28758ce9109b6709b743.txt',
#  '/kaggle/working/ultralytics/mydata/valid/labels/DYF6QC729W8N_jpg.rf.61b307bcbd1c9f396da79b62e2a31406.txt',
#  '/kaggle/working/ultralytics/mydata/valid/labels/2468210073_3a600cfbe8_o_jpg.rf.7d76ad216dc8596716ff3c310ff38305.txt',
# ...

# %%
# !ls
# Out:
# test  train  valid

# %%
#Train model for 200 epochs using yolov8n.pt
# !yolo task=detect mode=train model=/kaggle/input/v3-1-1-weights/best.pt data=/kaggle/input/marinev5/marinev5_kaggle/marinev5_kaggle/data.yaml epochs=200
# Out:
# Ultralytics YOLOv8.1.2 🚀 Python-3.10.12 torch-2.0.0 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
current_directory = os.getcwd()
print(current_directory)
# Out:
# /kaggle/working/ultralytics/mydata

# %%
cd /kaggle/working/ultralytics/mydata/runs
# Out:
# /kaggle/working/ultralytics/mydata/runs

# %%
# !ls
# Out:
# detect

# %%
import shutil

# Replace 'your_runs_folder_path' with the actual path to your 'runs' folder
runs_folder_path = '/kaggle/working/ultralytics/mydata/runs'

# Create a zip file of the 'runs' folder
shutil.make_archive("/kaggle/working/runs_archive", 'zip', runs_folder_path)
# Out:
# '/kaggle/working/runs_archive.zip'

# %%
from IPython.display import FileLink

FileLink(r'./kaggle/working/runs_archive.zip')
# Out:
# /kaggle/working/ultralytics/mydata/runs/kaggle/working/runs_archive.zip

# %%
#Check for Validation Data metrics
# !yolo task=detect mode=val model=/kaggle/working/ultralytics/mydata/runs/detect/train/weights/best.pt data=/kaggle/input/marinev5/marinev5_kaggle/marinev5_kaggle/data.yaml
# Out:
# Ultralytics YOLOv8.1.2 🚀 Python-3.10.12 torch-2.0.0 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 218 layers, 25842655 parameters, 0 gradients, 78.7 GFLOPs
# val: Scanning /kaggle/working/ultralytics/mydata/valid/labels.cache... 799 image
# WARNING ⚠️ Box and segment counts should be equal, but got len(segments) = 604, len(boxes) = 1854. To resolve this only boxes will be used and all segments will be removed. To avoid this please supply either a detect or segment dataset, not a detect-segment mixed dataset.
#                  Class     Images  Instances      Box(P          R      mAP50  mWARNING ⚠️ NMS time limit 1.300s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        799       1854      0.767      0.722      0.762      0.542
#                    eel        799        340      0.853      0.769      0.832      0.622
# ...

# %%
#Check for Test Data metrics
# !yolo task=detect mode=val model=/kaggle/working/ultralytics/mydata/runs/detect/train/weights/best.pt data=/kaggle/input/marinev5/marinev5_kaggle/marinev5_kaggle/data.yaml split=test
# Out:
# Ultralytics YOLOv8.1.2 🚀 Python-3.10.12 torch-2.0.0 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 218 layers, 25842655 parameters, 0 gradients, 78.7 GFLOPs
# val: Scanning /kaggle/working/ultralytics/mydata/test/labels... 410 images, 0 ba
# val: New cache created: /kaggle/working/ultralytics/mydata/test/labels.cache
# WARNING ⚠️ Box and segment counts should be equal, but got len(segments) = 309, len(boxes) = 1066. To resolve this only boxes will be used and all segments will be removed. To avoid this please supply either a detect or segment dataset, not a detect-segment mixed dataset.
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        410       1066      0.782      0.765      0.787      0.518
#                    eel        410        161      0.852       0.82      0.896      0.621
#                   fish        410        515      0.731      0.584      0.629      0.359
# ...

# %%
# Prediction on test dataset with 0.5 threshold
# !yolo task=detect mode=predict model=/kaggle/working/ultralytics/mydata/runs/detect/train/weights/best.pt conf=0.5 save_txt=True save_conf=True source=/kaggle/working/ultralytics/mydata/test/images
# Out:
# Ultralytics YOLOv8.1.2 🚀 Python-3.10.12 torch-2.0.0 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 218 layers, 25842655 parameters, 0 gradients, 78.7 GFLOPs
#
# image 1/410 /kaggle/working/ultralytics/mydata/test/images/08_12_27_22_png.rf.e5ac4fce367f0f57d407df6eefba9b68.jpg: 640x640 1 eel, 37.4ms
# image 2/410 /kaggle/working/ultralytics/mydata/test/images/09tb-lobsters1-videoSixteenByNineJumbo1600_jpg.rf.8e46ed85ef53f04a65d68dba26a46136.jpg: 640x640 1 lobster, 37.1ms
# image 3/410 /kaggle/working/ultralytics/mydata/test/images/0A5MVFX352GA_jpg.rf.6e50b62aa30e91abd76391fa99d27667.jpg: 640x640 1 eel, 37.1ms
# image 4/410 /kaggle/working/ultralytics/mydata/test/images/0BKZONCQ3XY8_jpg.rf.08127d321bd696aae6a1c3391e270858.jpg: 640x640 1 eel, 37.1ms
# image 5/410 /kaggle/working/ultralytics/mydata/test/images/0DSP57ATTEK6_jpg.rf.2207a11c59a795d19d758810bb9248e8.jpg: 640x640 1 eel, 37.0ms
# ...

# %%
#create a .zip file of the runs folder to download it
import shutil

# Replace 'your_runs_folder_path' with the actual path to your 'runs' folder
runs_folder_path = '/kaggle/working/ultralytics/mydata/runs'

# Create a zip file of the 'runs' folder
shutil.make_archive("/kaggle/working/runs_v5.2_thres50", 'zip', runs_folder_path)
# Out:
# '/kaggle/working/runs_v5.2_thres50.zip'

# %%
cd /kaggle/working/ultralytics/mydata
# Out:
# /kaggle/working/ultralytics/mydata

# %%
# !ls
# Out:
# runs  test  train  valid  yolov8n.pt

# %%
#Delete the .zip files
import os

# Specify the file name
file_to_delete = '/kaggle/working/runs_v4.2.zip'

# Construct the file path
file_path = '/kaggle/working/' + file_to_delete

# Check if the file exists before attempting to delete
if os.path.exists(file_path):
    # Delete the file
    os.remove(file_path)
    print(f'{file_to_delete} deleted successfully')
else:
    print(f'{file_to_delete} not found in the working directory')
# Out:
# /kaggle/working/runs_v4.2.zip not found in the working directory
